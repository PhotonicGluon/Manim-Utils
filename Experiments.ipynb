# %% [markdown]
# # Experiments

# %%
from manim import *

# %%
from manim_utils import *

# %%
vertices = [1, 2, 3, 4, 5, 6]
edges = [
    (1, 4),
    (2, 3),
    (3, 5),
    (4, 6),
    (5, 6),
    # (6, 3),  # WARN: (6,3) makes a cycle
    # (5, 2),  # WARN: (5,2) makes cycle and removes a source
]
# vertices = [1, 2, 3, 4, 5]
# edges = [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4), (1, 5), (2, 5), (3, 5), (4, 5)]

# %%
# %%manim --output_file hasse-graph.png GraphScene
#
# class GraphScene(Scene):
#     def construct(self):
#         g = HasseGraph(vertices, edges, layout="circular")
#         self.add(g)
# Out:
# Manim Community v0.18.1
# [10/28/24 08:18:43] INFO                                                                   ]8;id=618152;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=842000;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py#737\737]8;;\
#                              File ready at
#                              '/workspaces/Manim-Utils/media/images/Manim-Utils/hasse-graph
#                              .png'
#                     INFO     Rendered GraphScene                                                       ]8;id=708770;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=922415;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py#247\247]8;;\
#                              Played 0 animations
