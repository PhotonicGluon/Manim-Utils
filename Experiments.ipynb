# %% [markdown]
# # Experiments

# %%
from manim import *

# %%
from manim_utils import *

# %%
# %%manim --output_file hasse-graph.png -ql GraphScene
#
# class GraphScene(Scene):
#     def construct(self):
#         vertices = [1, 2, 3, 4, 5, 6]
#         edges = [
#             (1, 4),
#             (2, 3),
#             (3, 5),
#             (4, 6),
#             (5, 6),
#             # (6, 3),  # WARN: (6,3) makes a cycle
#             # (5, 2),  # WARN: (5,2) makes cycle and removes a source
#         ]
#
#         g = HasseGraph(vertices, edges)
#         self.add(g)
# Out:
# Manim Community v0.18.1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_cell_magic('manim', '--output_file hasse-graph.png -ql GraphScene', '\nclass GraphScene(Scene):\n    def construct(self):\n        vertices = [1, 2, 3, 4, 5, 6]\n        edges = [\n            (1, 4),\n            (2, 3),\n            (3, 5),\n            (4, 6),\n            (5, 6),\n            (6, 3),  # WARN: (6,3) makes a cycle\n            # (5, 2),  # WARN: (5,2) makes cycle and removes a source\n        ]\n\n        g = HasseGraph(vertices, edges)\n        self.add(g)\n')
#
# File ~/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/utils/ipython_magic.py:143, in ManimMagic.manim(self, line, cell, local_ns)
#     141     SceneClass = local_ns[config["scene_names"][0]]
#     142     scene = SceneClass(renderer=renderer)
# --> 143     scene.render()
#     144 finally:
#     145     # Shader cache becomes invalid as the context is destroyed
#     146     shader_program_cache.clear()
#
# File ~/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py:229, in Scene.render(self, preview)
#     227 self.setup()
#     228 try:
# --> 229     self.construct()
#     230 except EndSceneEarlyException:
#     231     pass
#
# File <string>:15, in construct(self)
#
# File /workspaces/Manim-Utils/manim_utils/hasse/hasse_graph.py:31, in HasseGraph.__init__(self, vertices, edges, label_colour, label_buff, **kwargs)
#      22 def __init__(
#      23     self,
#      24     vertices: List[Hashable],
#    (...)
#      29 ):
#      30     # Generate the internal DAG data
# ---> 31     self._dag = DAG(vertices, edges)
#      33     # Generate the Digraph
#      34     super().__init__(
#      35         vertices,
#      36         edges,
#    (...)
#      42         **kwargs
#      43     )
#
# File /workspaces/Manim-Utils/manim_utils/hasse/augmented_dag.py:44, in DAG.__init__(self, vertices, edges)
#      41 self._adj_list: Dict[Node, List[Node]] = self._generate_adjacency_list()
#      43 # Preprocessing
# ---> 44 self._compute_node_levels()
#      45 self._levels = self._arrange_node_levels()
#
# File /workspaces/Manim-Utils/manim_utils/hasse/augmented_dag.py:138, in DAG._compute_node_levels(self)
#     136 for source in sources:
#     137     if not self._is_acyclic(source):
# --> 138         raise ValueError("There is a cycle in the provided DAG")
#     140 # Push all the source nodes onto a stack
#     141 stack = [(source, -1) for source in sources]  # First is node, second is parent node's level
#
# ValueError: There is a cycle in the provided DAG

# %%
# %%manim --output_file hasse-graph.png -ql GraphScene
#
# class GraphScene(Scene):
#     def construct(self):
#         vertices = [1, 2, 3, 4, 5]
#         edges = [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4), (1, 5), (2, 5), (3, 5), (4, 5)]
#
#         g = HasseGraph(vertices, edges)
#         self.add(g)
# Out:
# Manim Community v0.18.1
# {1: array([-1.20023112, -4.        ,  0.        ]), 2: array([-0.41011704, -2.        ,  0.        ]), 3: array([-0.05911876,  0.        ,  0.        ]), 4: array([1.67853137, 2.        , 0.        ]), 5: array([3.11886091, 4.        , 0.        ])}
#                     INFO                                                                   ]8;id=732052;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=443143;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py#737\737]8;;\
#                              File ready at
#                              '/workspaces/Manim-Utils/media/images/Manim-Utils/hasse-graph
#                              .png'
#                     INFO     Rendered GraphScene                                                       ]8;id=800581;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=352944;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py#247\247]8;;\
#                              Played 0 animations

# %%
# %%manim --output_file hasse-graph.png -ql GraphScene
#
# class GraphScene(Scene):
#     def construct(self):
#         vertices = ["a", "b", "c", "d"]
#         edges = [
#             ("a", "c"),
#             ("b", "d"),
#             ("c", "d")
#         ]
#
#         g = HasseGraph(vertices, edges)
#         self.add(g)
# Out:
# Manim Community v0.18.1
# {'a': array([-0.34119067, -2.        ,  0.        ]), 'b': array([ 0.2370395, -2.       ,  0.       ]), 'c': array([1.7234138, 0.       , 0.       ]), 'd': array([2.15470429, 2.        , 0.        ])}
# [10/28/24 11:54:21] INFO                                                                   ]8;id=238968;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=810620;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py#737\737]8;;\
#                              File ready at
#                              '/workspaces/Manim-Utils/media/images/Manim-Utils/hasse-graph
#                              .png'
#                     INFO     Rendered GraphScene                                                       ]8;id=908573;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=105907;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py#247\247]8;;\
#                              Played 0 animations
