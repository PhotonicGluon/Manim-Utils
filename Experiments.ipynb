# %% [markdown]
# # Experiments

# %%
from manim import *

# %%
from manim_utils import *

# %%
# %%manim --output_file hasse-graph.png GraphScene
#
# class GraphScene(Scene):
#     def construct(self):
#         vertices = [1, 2, 3, 4, 5, 6]
#         edges = [
#             (1, 4),
#             (2, 3),
#             (3, 5),
#             (4, 6),
#             (5, 6),
#             # (6, 3),  # WARN: (6,3) makes a cycle
#             # (5, 2),  # WARN: (5,2) makes cycle and removes a source
#         ]
#         # vertices = [1, 2, 3, 4, 5]
#         # edges = [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4), (1, 5), (2, 5), (3, 5), (4, 5)]
#
#         g = HasseGraph(vertices, edges)
#         self.add(g)
# Out:
# Manim Community v0.18.1
# {1: array([-3., -3.,  0.]), 2: array([-2., -3.,  0.]), 3: array([-1., -1.,  0.]), 4: array([ 0., -1.,  0.]), 5: array([1., 1., 0.]), 6: array([2., 3., 0.])}
# [10/28/24 08:53:29] INFO                                                                   ]8;id=659181;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=486842;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py#737\737]8;;\
#                              File ready at
#                              '/workspaces/Manim-Utils/media/images/Manim-Utils/hasse-graph
#                              .png'
#                     INFO     Rendered GraphScene                                                       ]8;id=71559;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=221541;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py#247\247]8;;\
#                              Played 0 animations

# %%
# %%manim --output_file hasse-graph.png GraphScene
#
# class GraphScene(Scene):
#     def construct(self):
#         vertices = ["a", "b", "c", "d"]
#         edges = [
#             ("a", "c"),
#             ("b", "d"),
#             ("c", "d")
#         ]
#
#         g = HasseGraph(vertices, edges)
#         self.add(g)
# Out:
# Manim Community v0.18.1
# {'a': array([-2., -2.,  0.]), 'b': array([-1., -2.,  0.]), 'c': array([0., 0., 0.]), 'd': array([1., 2., 0.])}
#                     INFO                                                                   ]8;id=806311;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=683834;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene_file_writer.py#737\737]8;;\
#                              File ready at
#                              '/workspaces/Manim-Utils/media/images/Manim-Utils/hasse-graph
#                              .png'
#                     INFO     Rendered GraphScene                                                       ]8;id=221372;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=182074;file:///home/vscode/.cache/pypoetry/virtualenvs/manim-utils-nTB2-4Fm-py3.12/lib/python3.12/site-packages/manim/scene/scene.py#247\247]8;;\
#                              Played 0 animations
